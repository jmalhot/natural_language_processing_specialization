# %% [markdown]
# # Assignment 2: Naive Bayes
# Welcome to week two of this specialization. You will learn about Naive Bayes. Concretely, you will be using Naive Bayes for sentiment analysis on tweets. Given a tweet, you will decide if it has a positive sentiment or a negative one. Specifically you will:
#
# * Train a naive bayes model on a sentiment analysis task
# * Test using your model
# * Compute ratios of positive words to negative words
# * Do some error analysis
# * Predict on your own tweet
#
# You may already be familiar with Naive Bayes and its justification in terms of conditional probabilities and independence.
# * In this week's lectures and assignments we used the ratio of probabilities between positive and negative sentiments.
# * This approach gives us simpler formulas for these 2-way classification tasks.
#
# Load the cell below to import some packages.
# You  may want to browse the documentation of unfamiliar libraries and functions.

# %%
from utils import process_tweet, lookup
import pdb
from nltk.corpus import stopwords, twitter_samples
import numpy as np
import pandas as pd
import nltk
import string
from nltk.tokenize import TweetTokenizer
from os import getcwd

# %% [markdown]
# If you are running this notebook in your local computer,
# don't forget to download the twitter samples and stopwords from nltk.
#
# ```
# nltk.download('stopwords')
# nltk.download('twitter_samples')
# ```

# %%
# add folder, tmp2, from our local workspace containing pre-downloaded corpora files to nltk's data path
filePath = f"{getcwd()}/../tmp2/"
nltk.data.path.append(filePath)

# %%
# get the sets of positive and negative tweets
all_positive_tweets = twitter_samples.strings('positive_tweets.json')
all_negative_tweets = twitter_samples.strings('negative_tweets.json')

# split the data into two pieces, one for training and one for testing (validation set)
test_pos = all_positive_tweets[4000:]
train_pos = all_positive_tweets[:4000]
test_neg = all_negative_tweets[4000:]
train_neg = all_negative_tweets[:4000]

train_x = train_pos + train_neg
test_x = test_pos + test_neg

# avoid assumptions about the length of all_positive_tweets
train_y = np.append(np.ones(len(train_pos)), np.zeros(len(train_neg)))
test_y = np.append(np.ones(len(test_pos)), np.zeros(len(test_neg)))

# %% [markdown]
# # Part 1: Process the Data
#
# For any machine learning project, once you've gathered the data, the first step is to process it to make useful inputs to your model.
# - **Remove noise**: You will first want to remove noise from your data -- that is, remove words that don't tell you much about the content. These include all common words like 'I, you, are, is, etc...' that would not give us enough information on the sentiment.
# - We'll also remove stock market tickers, retweet symbols, hyperlinks, and hashtags because they can not tell you a lot of information on the sentiment.
# - You also want to remove all the punctuation from a tweet. The reason for doing this is because we want to treat words with or without the punctuation as the same word, instead of treating "happy", "happy?", "happy!", "happy," and "happy." as different words.
# - Finally you want to use stemming to only keep track of one variation of each word. In other words, we'll treat "motivation", "motivated", and "motivate" similarly by grouping them within the same stem of "motiv-".
#
# We have given you the function `process_tweet()` that does this for you.

# %%
custom_tweet = "RT @Twitter @chapagain Hello There! Have a great day. :) #good #morning http://chapagain.com.np"

# print cleaned tweet
print(process_tweet(custom_tweet))
# Out:
# ['hello', 'great', 'day', ':)', 'good', 'morn']

# %% [markdown]
# ## Part 1.1 Implementing your helper functions
#
# To help train your naive bayes model, you will need to build a dictionary where the keys are a (word, label) tuple and the values are the corresponding frequency.  Note that the labels we'll use here are 1 for positive and 0 for negative.
#
# You will also implement a `lookup()` helper function that takes in the `freqs` dictionary, a word, and a label (1 or 0) and returns the number of times that word and label tuple appears in the collection of tweets.
#
# For example: given a list of tweets `["i am rather excited", "you are rather happy"]` and the label 1, the function will return a dictionary that contains the following key-value pairs:
#
# {
#     ("rather", 1): 2
#     ("happi", 1) : 1
#     ("excit", 1) : 1
# }
#
# - Notice how for each word in the given string, the same label 1 is assigned to each word.
# - Notice how the words "i" and "am" are not saved, since it was removed by process_tweet because it is a stopword.
# - Notice how the word "rather" appears twice in the list of tweets, and so its count value is 2.
#
# #### Instructions
# Create a function `count_tweets()` that takes a list of tweets as input, cleans all of them, and returns a dictionary.
# - The key in the dictionary is a tuple containing the stemmed word and its class label, e.g. ("happi",1).
# - The value the number of times this word appears in the given collection of tweets (an integer).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>Please use the `process_tweet` function that was imported above, and then store the words in their respective dictionaries and sets.</li>
#     <li>You may find it useful to use the `zip` function to match each element in `tweets` with each element in `ys`.</li>
#     <li>Remember to check if the key in the dictionary exists before adding that key to the dictionary, or incrementing its value.</li>
#     <li>Assume that the `result` dictionary that is input will contain clean key-value pairs (you can assume that the values will be integers that can be incremented).  It is good practice to check the datatype before incrementing the value, but it's not required here.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def count_tweets(result, tweets, ys):
    '''
    Input:
        result: a dictionary that will be used to map each pair to its frequency
        tweets: a list of tweets
        ys: a list corresponding to the sentiment of each tweet (either 0 or 1)
    Output:
        result: a dictionary mapping each pair to its frequency
    '''

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    for y, tweet in zip(ys, tweets):
        for word in process_tweet(tweet):
            # define the key, which is the word and label tuple
            pair = (word, y)

            # if the key exists in the dictionary, increment the count
            if pair in result:
                result[pair] += 1

            # else, if the key is new, add it to the dictionary and set the count to 1
            else:
                result[pair] = 1
    ### END CODE HERE ###

    return result

# %%
# Testing your function


result = {}
tweets = ['i am happy', 'i am tricked', 'i am sad', 'i am tired', 'i am tired']
ys = [1, 0, 0, 0, 0]
count_tweets(result, tweets, ys)
# Out:
# {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# **Expected Output**: {('happi', 1): 1, ('trick', 0): 1, ('sad', 0): 1, ('tire', 0): 2}

# %% [markdown]
# # Part 2: Train your model using Naive Bayes
#
# Naive bayes is an algorithm that could be used for sentiment analysis. It takes a short time to train and also has a short prediction time.
#
# #### So how do you train a Naive Bayes classifier?
# - The first part of training a naive bayes classifier is to identify the number of classes that you have.
# - You will create a probability for each class.
# $P(D_{pos})$ is the probability that the document is positive.
# $P(D_{neg})$ is the probability that the document is negative.
# Use the formulas as follows and store the values in a dictionary:
#
# $$P(D_{pos}) = \frac{D_{pos}}{D}\tag{1}$$
#
# $$P(D_{neg}) = \frac{D_{neg}}{D}\tag{2}$$
#
# Where $D$ is the total number of documents, or tweets in this case, $D_{pos}$ is the total number of positive tweets and $D_{neg}$ is the total number of negative tweets.

# %% [markdown]
# #### Prior and Logprior
#
# The prior probability represents the underlying probability in the target population that a tweet is positive versus negative.  In other words, if we had no specific information and blindly picked a tweet out of the population set, what is the probability that it will be positive versus that it will be negative? That is the "prior".
#
# The prior is the ratio of the probabilities $\frac{P(D_{pos})}{P(D_{neg})}$.
# We can take the log of the prior to rescale it, and we'll call this the logprior
#
# $$\text{logprior} = log \left( \frac{P(D_{pos})}{P(D_{neg})} \right) = log \left( \frac{D_{pos}}{D_{neg}} \right)$$.
#
# Note that $log(\frac{A}{B})$ is the same as $log(A) - log(B)$.  So the logprior can also be calculated as the difference between two logs:
#
# $$\text{logprior} = \log (P(D_{pos})) - \log (P(D_{neg})) = \log (D_{pos}) - \log (D_{neg})\tag{3}$$

# %% [markdown]
# #### Positive and Negative Probability of a Word
# To compute the positive probability and the negative probability for a specific word in the vocabulary, we'll use the following inputs:
#
# - $freq_{pos}$ and $freq_{neg}$ are the frequencies of that specific word in the positive or negative class. In other words, the positive frequency of a word is the number of times the word is counted with the label of 1.
# - $N_{pos}$ and $N_{neg}$ are the total number of positive and negative words for all documents (for all tweets), respectively.
# - $V$ is the number of unique words in the entire set of documents, for all classes, whether positive or negative.
#
# We'll use these to compute the positive and negative probability for a specific word using this formula:
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# Notice that we add the "+1" in the numerator for additive smoothing.  This [wiki article](https://en.wikipedia.org/wiki/Additive_smoothing) explains more about additive smoothing.

# %% [markdown]
# #### Log likelihood
# To compute the loglikelihood of that very same word, we can implement the following equations:
#
# $$\text{loglikelihood} = \log \left(\frac{P(W_{pos})}{P(W_{neg})} \right)\tag{6}$$

# %% [markdown]
# ##### Create `freqs` dictionary
# - Given your `count_tweets()` function, you can compute a dictionary called `freqs` that contains all the frequencies.
# - In this `freqs` dictionary, the key is the tuple (word, label)
# - The value is the number of times it has appeared.
#
# We will use this dictionary in several parts of this assignment.

# %%
# Build the freqs dictionary for later uses

freqs = count_tweets({}, train_x, train_y)

# %% [markdown]
# #### Instructions
# Given a freqs dictionary, `train_x` (a list of tweets) and a `train_y` (a list of labels for each tweet), implement a naive bayes classifier.
#
# ##### Calculate $V$
# - You can then compute the number of unique words that appear in the `freqs` dictionary to get your $V$ (you can use the `set` function).
#
# ##### Calculate $freq_{pos}$ and $freq_{neg}$
# - Using your `freqs` dictionary, you can compute the positive and negative frequency of each word $freq_{pos}$ and $freq_{neg}$.
#
# ##### Calculate $N_{pos}$, $N_{neg}$, $V_{pos}$, and $V_{neg}$
# - Using `freqs` dictionary, you can also compute the total number of positive words and total number of negative words $N_{pos}$ and $N_{neg}$.
# - Similarly, use `freqs` dictionary to compute the total number of **unique** positive words, $V_{pos}$, and total **unique** negative words $V_{neg}$.
#
# ##### Calculate $D$, $D_{pos}$, $D_{neg}$
# - Using the `train_y` input list of labels, calculate the number of documents (tweets) $D$, as well as the number of positive documents (tweets) $D_{pos}$ and number of negative documents (tweets) $D_{neg}$.
# - Calculate the probability that a document (tweet) is positive $P(D_{pos})$, and the probability that a document (tweet) is negative $P(D_{neg})$
#
# ##### Calculate the logprior
# - the logprior is $log(D_{pos}) - log(D_{neg})$
#
# ##### Calculate log likelihood
# - Finally, you can iterate over each word in the vocabulary, use your `lookup` function to get the positive frequencies, $freq_{pos}$, and the negative frequencies, $freq_{neg}$, for that specific word.
# - Compute the positive probability of each word $P(W_{pos})$, negative probability of each word $P(W_{neg})$ using equations 4 & 5.
#
# $$ P(W_{pos}) = \frac{freq_{pos} + 1}{N_{pos} + V}\tag{4} $$
# $$ P(W_{neg}) = \frac{freq_{neg} + 1}{N_{neg} + V}\tag{5} $$
#
# **Note:** We'll use a dictionary to store the log likelihoods for each word.  The key is the word, the value is the log likelihood of that word).
#
# - You can then compute the loglikelihood: $log \left( \frac{P(W_{pos})}{P(W_{neg})} \right)$.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def train_naive_bayes(freqs, train_x, train_y):
    '''
    Input:
        freqs: dictionary from (word, label) to how often the word appears
        train_x: a list of tweets
        train_y: a list of labels correponding to the tweets (0,1)
    Output:
        logprior: the log prior. (equation 3 above)
        loglikelihood: the log likelihood of you Naive bayes equation. (equation 6 above)
    '''
    
    loglikelihood = {}
    logprior = 0
    
    #freqs=process_tweet(freqs)

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###

    # calculate V, the number of unique words in the vocabulary
    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    # calculate N_pos, N_neg, V_pos, V_neg
    N_pos = N_neg = V_pos = V_neg = 0
    for pair in freqs.keys():
        # if the label is positive (greater than zero)
        if pair[1] > 0:
            # increment the count of unique positive words by 1
            V_pos += 1

            # Increment the number of positive words by the count for this (word, label) pair
            N_pos += freqs.get((pair[0], 1.0), 0) #lookup(freqs,pair[0],pair[1]) #

        # else, the label is negative
        else:
            # increment the count of unique negative words by 1
            V_neg += 1

            # increment the number of negative words by the count for this (word,label) pair
            N_neg += freqs.get((pair[0], 0.0), 0) #lookup(freqs,pair[0],pair[1])

    # Calculate D, the number of documents
    D = len(train_y)

    # Calculate D_pos, the number of positive documents
    #D_pos = (train_y==1).sum()
    D_pos = len(list(filter(lambda x: x == 1, train_y)))
    

    # Calculate D_neg, the number of negative documents
    #D_neg = (train_y==0).sum()
    
    D_neg = len(list(filter(lambda x: x == 0, train_y)))
    
    # Calculate logprior
    logprior = np.log(D_pos) - np.log(D_neg)

    # For each word in the vocabulary...
    for word in vocab:
        # get the positive and negative frequency of the word
        freq_pos = freqs.get((word, 1.0), 0) #lookup(freqs,word,1) 
        freq_neg = freqs.get((word, 0.0), 0) #lookup(freqs,word,0)

        # calculate the probability that each word is positive, and negative
        #p_w_pos = (freq_pos+1)/N_pos+V
        #p_w_neg = (freq_neg+1)/N_neg+V
        
        p_w_pos = D_pos/D
        p_w_neg = D_neg/D
        
        
        # calculate the log likelihood of the word
        #loglikelihood[word] = np.log((p_w_pos)/(p_w_neg))
        
        loglikelihood[word] =(np.log ((freq_pos+1)/(N_pos+V))) - (np.log ((freq_neg+1)/(N_neg+V)))
        
        #d = {word:np.log((p_w_pos)/(p_w_neg))}
        #loglikelihood.update(d)

        ### END CODE HERE ###
        

    return logprior, loglikelihood

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 0.0
# 9089

# %% [markdown]
# **Expected Output**:
#
# 0.0
#
# 9089

# %% [markdown]
# # Part 3: Test your naive bayes
#
# Now that we have the `logprior` and `loglikelihood`, we can test the naive bayes function by making predicting on some tweets!
#
# #### Implement `naive_bayes_predict`
# **Instructions**:
# Implement the `naive_bayes_predict` function to make predictions on tweets.
# * The function takes in the `tweet`, `logprior`, `loglikelihood`.
# * It returns the probability that the tweet belongs to the positive or negative class.
# * For each tweet, sum up loglikelihoods of each word in the tweet.
# * Also add the logprior to this sum to get the predicted sentiment of that tweet.
#
# $$ p = logprior + \sum_i^N (loglikelihood_i)$$
#
# #### Note
# Note we calculate the prior from the training data, and that the training data is evenly split between positive and negative labels (4000 positive and 4000 negative tweets).  This means that the ratio of positive to negative 1, and the logprior is 0.
#
# The value of 0.0 means that when we add the logprior to the log likelihood, we're just adding zero to the log likelihood.  However, please remember to include the logprior, because whenever the data is not perfectly balanced, the logprior will be a non-zero value.

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def naive_bayes_predict(tweet, logprior, loglikelihood):
    '''
    Input:
        tweet: a string
        logprior: a number
        loglikelihood: a dictionary of words mapping to numbers
    Output:
        p: the sum of all the logliklihoods of each word in the tweet (if found in the dictionary) + logprior (a number)

    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # process the tweet to get a list of words
    word_l = process_tweet(tweet)

    # initialize probability to zero
    p = 0

    # add the logprior
    p += logprior

    for word in word_l:

        # check if the word exists in the loglikelihood dictionary
        if word in loglikelihood:
            # add the log likelihood of that word to the probability
            p += loglikelihood[word]

    ### END CODE HERE ###

    return p

# %%
loglikelihood['smile']
# Out:
# 1.5740278623499178

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything
# Experiment with your own tweet.
my_tweet = 'She smiled.'
p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print('The expected output is',p)
# Out:
# The expected output is 1.5740278623499178

# %% [markdown]
# **Expected Output**:
# - The expected output is around 1.57
# - The sentiment is positive.

# %% [markdown]
# #### Implement test_naive_bayes
# **Instructions**:
# * Implement `test_naive_bayes` to check the accuracy of your predictions.
# * The function takes in your `test_x`, `test_y`, log_prior, and loglikelihood
# * It returns the accuracy of your model.
# * First, use `naive_bayes_predict` function to make predictions for each tweet in text_x.

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    """
    Input:
        test_x: A list of tweets
        test_y: the corresponding labels for the list of tweets
        logprior: the logprior
        loglikelihood: a dictionary with the loglikelihoods for each word
    Output:
        accuracy: (# of tweets classified correctly)/(total # of tweets)
    """
    accuracy = 0  # return this properly

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    y_hats = []
    for tweet in test_x:
        # if the prediction is > 0
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            # the predicted class is 1
            y_hat_i = 1
        else:
            # otherwise the predicted class is 0
            y_hat_i = 0

        # append the predicted class to the list y_hats
        y_hats.append(y_hat_i)

    # error is the average of the absolute values of the differences between y_hats and test_y
    error = np.sum(np.asarray(y_hats) == test_y.reshape(1,-1))/len(np.squeeze(test_y))

    # Accuracy is 1 minus the error
    accuracy = error

    ### END CODE HERE ###

    return accuracy

# %%
print("Naive Bayes accuracy = %0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy = 0.9940

# %% [markdown]
# **Expected Accuracy**:
#
# 0.9940

# %%
# UNQ_C7 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
# You do not have to input any code in this cell, but it is relevant to grading, so please do not change anything

# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    # print( '%s -> %f' % (tweet, naive_bayes_predict(tweet, logprior, loglikelihood)))
    p = naive_bayes_predict(tweet, logprior, loglikelihood)
#     print(f'{tweet} -> {p:.2f} ({p_category})')
    print(f'{tweet} -> {p:.2f}')
# Out:
# I am happy -> 2.15
# I am bad -> -1.29
# this movie should have been great. -> 2.14
# great -> 2.14
# great great -> 4.28
# great great great -> 6.41
# great great great great -> 8.55

# %% [markdown]
# **Expected Output**:
# - I am happy -> 2.15
# - I am bad -> -1.29
# - this movie should have been great. -> 2.14
# - great -> 2.14
# - great great -> 4.28
# - great great great -> 6.41
# - great great great great -> 8.55

# %%
# Feel free to check the sentiment of your own tweet below
my_tweet = 'you are bad :('
naive_bayes_predict(my_tweet, logprior, loglikelihood)
# Out:
# -8.801622640492193

# %% [markdown]
# # Part 4: Filter words by Ratio of positive to negative counts
#
# - Some words have more positive counts than others, and can be considered "more positive".  Likewise, some words can be considered more negative than others.
# - One way for us to define the level of positiveness or negativeness, without calculating the log likelihood, is to compare the positive to negative frequency of the word.
#     - Note that we can also use the log likelihood calculations to compare relative positivity or negativity of words.
# - We can calculate the ratio of positive to negative frequencies of a word.
# - Once we're able to calculate these ratios, we can also filter a subset of words that have a minimum ratio of positivity / negativity or higher.
# - Similarly, we can also filter a subset of words that have a maximum ratio of positivity / negativity or lower (words that are at least as negative, or even more negative than a given threshold).
#
# #### Implement `get_ratio()`
# - Given the `freqs` dictionary of words and a particular word, use `lookup(freqs,word,1)` to get the positive count of the word.
# - Similarly, use the `lookup()` function to get the negative count of that word.
# - Calculate the ratio of positive divided by negative counts
#
# $$ ratio = \frac{\text{pos_words} + 1}{\text{neg_words} + 1} $$
#
# Where pos_words and neg_words correspond to the frequency of the words in their respective classes.
# <table>
#     <tr>
#         <td>
#             <b>Words</b>
#         </td>
#         <td>
#         Positive word count
#         </td>
#          <td>
#         Negative Word Count
#         </td>
#   </tr>
#     <tr>
#         <td>
#         glad
#         </td>
#          <td>
#         41
#         </td>
#     <td>
#         2
#         </td>
#   </tr>
#     <tr>
#         <td>
#         arriv
#         </td>
#          <td>
#         57
#         </td>
#     <td>
#         4
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :(
#         </td>
#          <td>
#         1
#         </td>
#     <td>
#         3663
#         </td>
#   </tr>
#     <tr>
#         <td>
#         :-(
#         </td>
#          <td>
#         0
#         </td>
#     <td>
#         378
#         </td>
#   </tr>
# </table>

# %%
# UNQ_C8 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_ratio(freqs, word):
    '''
    Input:
        freqs: dictionary containing the words

    Output: a dictionary with keys 'positive', 'negative', and 'ratio'.
        Example: {'positive': 10, 'negative': 20, 'ratio': 0.5}
    '''
    pos_neg_ratio = {'positive': 0, 'negative': 0, 'ratio': 0.0}
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # use lookup() to find positive counts for the word (denoted by the integer 1)
    pos_neg_ratio['positive'] = lookup(freqs,word,1)

    # use lookup() to find negative counts for the word (denoted by integer 0)
    pos_neg_ratio['negative'] = lookup(freqs,word,0)

    # calculate the ratio of positive to negative counts for the word
    pos_neg_ratio['ratio'] =  (pos_neg_ratio['positive']) + 1 /  ( pos_neg_ratio['negative'] + 1)
    ### END CODE HERE ###
    return pos_neg_ratio

# %%
get_ratio(freqs, 'happi')
# Out:
# {'positive': 161, 'negative': 18, 'ratio': 161.05263157894737}

# %%
get_ratio(freqs, 'happi')['ratio']
# Out:
# 161.05263157894737

# %% [markdown]
# #### Implement `get_words_by_threshold(freqs,label,threshold)`
#
# * If we set the label to 1, then we'll look for all words whose threshold of positive/negative is at least as high as that threshold, or higher.
# * If we set the label to 0, then we'll look for all words whose threshold of positive/negative is at most as low as the given threshold, or lower.
# * Use the `get_ratio()` function to get a dictionary containing the positive count, negative count, and the ratio of positive to negative counts.
# * Append a dictionary to a list, where the key is the word, and the dictionary is the dictionary `pos_neg_ratio` that is returned by the `get_ratio()` function.
# An example key-value pair would have this structure:
# ```
# {'happi':
#     {'positive': 10, 'negative': 20, 'ratio': 0.5}
# }
# ```

# %%
# UNQ_C9 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def get_words_by_threshold(freqs, label, threshold):
    '''
    Input:
        freqs: dictionary of words
        pos_neg_ratio: dictionary of positive counts, negative counts, and ratio of positive / negative counts.
        label: 1 for positive, 0 for negative
        threshold: ratio that will be used as the cutoff for including a word in the returned dictionary
    Output:
        word_set: dictionary containing the word and information on its positive count, negative count, and ratio of positive to negative counts.
        example of a key value pair:
        {'happi':
            {'positive': 10, 'negative': 20, 'ratio': 0.5}
        }
    '''
    word_list = {}

    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    for key in freqs.keys():
        word, _ = key

        # get the positive/negative ratio for a word
        pos_neg_ratio = get_ratio(freqs,word)['ratio']

        # if the label is 1 and the ratio is greater than or equal to the threshold...
        if label == 1 and pos_neg_ratio >= threshold:

            # Add the pos_neg_ratio to the dictionary
            d = {word:get_ratio(freqs,word)}
            word_list.update(d)

        # If the label is 0 and the pos_neg_ratio is less than or equal to the threshold...
        elif label == 0 and pos_neg_ratio <= threshold:

            # Add the pos_neg_ratio to the dictionary
            d = {word:get_ratio(freqs,word)}
            word_list.update(d)

        # otherwise, do not include this word in the list (do nothing)

    ### END CODE HERE ###
    return word_list

# %%
# Test your function: find negative words at or below a threshold
get_words_by_threshold(freqs, label=0, threshold=0.05)
# Out:
# {':-(': {'positive': 0, 'negative': 378, 'ratio': 0.002638522427440633},
#  'zayniscomingbackonjuli': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '26': {'positive': 0, 'negative': 20, 'ratio': 0.047619047619047616},
#  '>:(': {'positive': 0, 'negative': 43, 'ratio': 0.022727272727272728},
#  'lost': {'positive': 0, 'negative': 19, 'ratio': 0.05},
#  '♛': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  '》': {'positive': 0, 'negative': 210, 'ratio': 0.004739336492890996},
#  'beli̇ev': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'wi̇ll': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'justi̇n': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｓｅｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776},
#  'ｍｅ': {'positive': 0, 'negative': 35, 'ratio': 0.027777777777777776}}

# %%
# Test your function; find positive words at or above a threshold
get_words_by_threshold(freqs, label=1, threshold=10)
# Out:
# {'followfriday': {'positive': 23, 'negative': 0, 'ratio': 24.0},
#  'top': {'positive': 30, 'negative': 5, 'ratio': 30.166666666666668},
#  'member': {'positive': 14, 'negative': 6, 'ratio': 14.142857142857142},
#  'commun': {'positive': 27, 'negative': 1, 'ratio': 27.5},
#  'week': {'positive': 72, 'negative': 47, 'ratio': 72.02083333333333},
#  ':)': {'positive': 2847, 'negative': 2, 'ratio': 2847.3333333333335},
#  'hey': {'positive': 60, 'negative': 20, 'ratio': 60.04761904761905},
#  'pleas': {'positive': 80, 'negative': 243, 'ratio': 80.00409836065573},
#  'call': {'positive': 27, 'negative': 22, 'ratio': 27.043478260869566},
#  'mani': {'positive': 28, 'negative': 24, 'ratio': 28.04},
#  'thank': {'positive': 504, 'negative': 94, 'ratio': 504.0105263157895},
#  'listen': {'positive': 14, 'negative': 14, 'ratio': 14.066666666666666},
#  'last': {'positive': 39, 'negative': 51, 'ratio': 39.01923076923077},
#  'night': {'positive': 55, 'negative': 33, 'ratio': 55.029411764705884},
#  'amaz': {'positive': 41, 'negative': 12, 'ratio': 41.07692307692308},
#  'congrat': {'positive': 15, 'negative': 2, 'ratio': 15.333333333333334},
#  'got': {'positive': 57, 'negative': 90, 'ratio': 57.010989010989015},
#  'day': {'positive': 187, 'negative': 114, 'ratio': 187.0086956521739},
#  'one': {'positive': 90, 'negative': 117, 'ratio': 90.00847457627118},
#  'flipkartfashionfriday': {'positive': 16, 'negative': 0, 'ratio': 17.0},
#  'like': {'positive': 187, 'negative': 182, 'ratio': 187.0054644808743},
#  'keep': {'positive': 55, 'negative': 31, 'ratio': 55.03125},
#  'love': {'positive': 336, 'negative': 128, 'ratio': 336.0077519379845},
#  'wait': {'positive': 55, 'negative': 36, 'ratio': 55.027027027027025},
#  'long': {'positive': 27, 'negative': 33, 'ratio': 27.029411764705884},
#  'hope': {'positive': 113, 'negative': 91, 'ratio': 113.01086956521739},
#  'enjoy': {'positive': 57, 'negative': 7, 'ratio': 57.125},
#  'happi': {'positive': 161, 'negative': 18, 'ratio': 161.05263157894737},
#  'friday': {'positive': 91, 'negative': 9, 'ratio': 91.1},
#  'thought': {'positive': 21, 'negative': 28, 'ratio': 21.03448275862069},
#  '’': {'positive': 17, 'negative': 20, 'ratio': 17.047619047619047},
#  'enough': {'positive': 16, 'negative': 18, 'ratio': 16.05263157894737},
#  'time': {'positive': 100, 'negative': 125, 'ratio': 100.0079365079365},
#  'new': {'positive': 111, 'negative': 43, 'ratio': 111.02272727272727},
#  'must': {'positive': 14, 'negative': 12, 'ratio': 14.076923076923077},
#  'go': {'positive': 120, 'negative': 181, 'ratio': 120.00549450549451},
#  ':D': {'positive': 498, 'negative': 0, 'ratio': 499.0},
#  'app': {'positive': 12, 'negative': 12, 'ratio': 12.076923076923077},
#  'well': {'positive': 66, 'negative': 49, 'ratio': 66.02},
#  '…': {'positive': 31, 'negative': 14, 'ratio': 31.066666666666666},
#  'name': {'positive': 12, 'negative': 13, 'ratio': 12.071428571428571},
#  ':p': {'positive': 103, 'negative': 0, 'ratio': 104.0},
#  'influenc': {'positive': 16, 'negative': 0, 'ratio': 17.0},
#  'big': {'positive': 27, 'negative': 17, 'ratio': 27.055555555555557},
#  '...': {'positive': 227, 'negative': 282, 'ratio': 227.0035335689046},
#  'selfi': {'positive': 11, 'negative': 5, 'ratio': 11.166666666666666},
#  'follow': {'positive': 319, 'negative': 245, 'ratio': 319.0040650406504},
#  'perfect': {'positive': 17, 'negative': 2, 'ratio': 17.333333333333332},
#  'alreadi': {'positive': 19, 'negative': 41, 'ratio': 19.023809523809526},
#  'know': {'positive': 120, 'negative': 110, 'ratio': 120.009009009009},
#  "what'": {'positive': 14, 'negative': 13, 'ratio': 14.071428571428571},
#  'great': {'positive': 134, 'negative': 15, 'ratio': 134.0625},
#  'opportun': {'positive': 17, 'negative': 1, 'ratio': 17.5},
#  'get': {'positive': 164, 'negative': 181, 'ratio': 164.0054945054945},
#  'today': {'positive': 86, 'negative': 88, 'ratio': 86.01123595505618},
#  'job': {'positive': 34, 'negative': 8, 'ratio': 34.111111111111114},
#  ':-)': {'positive': 543, 'negative': 0, 'ratio': 544.0},
#  'help': {'positive': 37, 'negative': 44, 'ratio': 37.022222222222226},
#  "here'": {'positive': 20, 'negative': 0, 'ratio': 21.0},
#  'work': {'positive': 88, 'negative': 102, 'ratio': 88.00970873786407},
#  'hi': {'positive': 154, 'negative': 28, 'ratio': 154.0344827586207},
#  'hello': {'positive': 49, 'negative': 8, 'ratio': 49.111111111111114},
#  'need': {'positive': 62, 'negative': 86, 'ratio': 62.01149425287356},
#  'someth': {'positive': 25, 'negative': 21, 'ratio': 25.045454545454547},
#  'u': {'positive': 136, 'negative': 151, 'ratio': 136.0065789473684},
#  'twitter': {'positive': 25, 'negative': 20, 'ratio': 25.047619047619047},
#  '—': {'positive': 22, 'negative': 18, 'ratio': 22.05263157894737},
#  'sure': {'positive': 37, 'negative': 26, 'ratio': 37.03703703703704},
#  'thing': {'positive': 48, 'negative': 43, 'ratio': 48.02272727272727},
#  'dm': {'positive': 34, 'negative': 20, 'ratio': 34.04761904761905},
#  'x': {'positive': 50, 'negative': 35, 'ratio': 50.02777777777778},
#  "i'v": {'positive': 25, 'negative': 64, 'ratio': 25.015384615384615},
#  'pretti': {'positive': 17, 'negative': 12, 'ratio': 17.076923076923077},
#  'fun': {'positive': 45, 'negative': 20, 'ratio': 45.04761904761905},
#  'yeah': {'positive': 30, 'negative': 35, 'ratio': 30.02777777777778},
#  'lol': {'positive': 48, 'negative': 31, 'ratio': 48.03125},
#  'bit': {'positive': 16, 'negative': 12, 'ratio': 16.076923076923077},
#  'youth': {'positive': 14, 'negative': 0, 'ratio': 15.0},
#  'year': {'positive': 33, 'negative': 37, 'ratio': 33.026315789473685},
#  'music': {'positive': 15, 'negative': 12, 'ratio': 15.076923076923077},
#  'dream': {'positive': 17, 'negative': 17, 'ratio': 17.055555555555557},
#  'left': {'positive': 10, 'negative': 22, 'ratio': 10.043478260869565},
#  'see': {'positive': 156, 'negative': 104, 'ratio': 156.0095238095238},
#  'send': {'positive': 17, 'negative': 7, 'ratio': 17.125},
#  'us': {'positive': 91, 'negative': 33, 'ratio': 91.02941176470588},
#  'email': {'positive': 22, 'negative': 10, 'ratio': 22.09090909090909},
#  "we'll": {'positive': 12, 'negative': 6, 'ratio': 12.142857142857142},
#  'kik': {'positive': 16, 'negative': 55, 'ratio': 16.017857142857142},
#  'come': {'positive': 63, 'negative': 72, 'ratio': 63.013698630136986},
#  'releas': {'positive': 11, 'negative': 5, 'ratio': 11.166666666666666},
#  'link': {'positive': 13, 'negative': 9, 'ratio': 13.1},
#  'bam': {'positive': 44, 'negative': 0, 'ratio': 45.0},
#  'bestfriend': {'positive': 50, 'negative': 6, 'ratio': 50.142857142857146},
#  'lot': {'positive': 80, 'negative': 18, 'ratio': 80.05263157894737},
#  'warsaw': {'positive': 44, 'negative': 0, 'ratio': 45.0},
#  '<3': {'positive': 118, 'negative': 19, 'ratio': 118.05},
#  'everyon': {'positive': 45, 'negative': 18, 'ratio': 45.05263157894737},
#  'watch': {'positive': 32, 'negative': 57, 'ratio': 32.01724137931034},
#  'support': {'positive': 25, 'negative': 24, 'ratio': 25.04},
#  'oh': {'positive': 44, 'negative': 78, 'ratio': 44.0126582278481},
#  'look': {'positive': 109, 'negative': 79, 'ratio': 109.0125},
#  'forward': {'positive': 20, 'negative': 5, 'ratio': 20.166666666666668},
#  'visit': {'positive': 25, 'negative': 10, 'ratio': 25.09090909090909},
#  'next': {'positive': 37, 'negative': 31, 'ratio': 37.03125},
#  'make': {'positive': 69, 'negative': 90, 'ratio': 69.01098901098901},
#  'feel': {'positive': 33, 'negative': 131, 'ratio': 33.00757575757576},
#  'better': {'positive': 40, 'negative': 31, 'ratio': 40.03125},
#  'never': {'positive': 31, 'negative': 42, 'ratio': 31.023255813953487},
#  'good': {'positive': 191, 'negative': 83, 'ratio': 191.01190476190476},
#  'girl': {'positive': 34, 'negative': 17, 'ratio': 34.05555555555556},
#  'best': {'positive': 49, 'negative': 16, 'ratio': 49.05882352941177},
#  'wish': {'positive': 29, 'negative': 63, 'ratio': 29.015625},
#  'reason': {'positive': 10, 'negative': 3, 'ratio': 10.25},
#  'shout': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'ad': {'positive': 10, 'negative': 1, 'ratio': 10.5},
#  'video': {'positive': 29, 'negative': 20, 'ratio': 29.047619047619047},
#  'would': {'positive': 70, 'negative': 54, 'ratio': 70.01818181818182},
#  'dear': {'positive': 15, 'negative': 11, 'ratio': 15.083333333333334},
#  'okay': {'positive': 31, 'negative': 29, 'ratio': 31.033333333333335},
#  ';)': {'positive': 22, 'negative': 0, 'ratio': 23.0},
#  'haha': {'positive': 44, 'negative': 24, 'ratio': 44.04},
#  'im': {'positive': 38, 'negative': 108, 'ratio': 38.00917431192661},
#  'kid': {'positive': 13, 'negative': 16, 'ratio': 13.058823529411764},
#  'stuff': {'positive': 11, 'negative': 8, 'ratio': 11.11111111111111},
#  'product': {'positive': 11, 'negative': 3, 'ratio': 11.25},
#  'shop': {'positive': 12, 'negative': 8, 'ratio': 12.11111111111111},
#  'check': {'positive': 38, 'negative': 16, 'ratio': 38.05882352941177},
#  'talk': {'positive': 37, 'negative': 40, 'ratio': 37.02439024390244},
#  'someon': {'positive': 29, 'negative': 39, 'ratio': 29.025},
#  'text': {'positive': 12, 'negative': 13, 'ratio': 12.071428571428571},
#  'ye': {'positive': 60, 'negative': 39, 'ratio': 60.025},
#  'hear': {'positive': 24, 'negative': 26, 'ratio': 24.037037037037038},
#  'beauti': {'positive': 45, 'negative': 10, 'ratio': 45.09090909090909},
#  'till': {'positive': 16, 'negative': 6, 'ratio': 16.142857142857142},
#  'chang': {'positive': 20, 'negative': 23, 'ratio': 20.041666666666668},
#  'god': {'positive': 14, 'negative': 13, 'ratio': 14.071428571428571},
#  'babi': {'positive': 17, 'negative': 37, 'ratio': 17.026315789473685},
#  'cute': {'positive': 21, 'negative': 37, 'ratio': 21.026315789473685},
#  "can't": {'positive': 31, 'negative': 148, 'ratio': 31.006711409395972},
#  'yet': {'positive': 12, 'negative': 29, 'ratio': 12.033333333333333},
#  'still': {'positive': 37, 'negative': 104, 'ratio': 37.00952380952381},
#  'think': {'positive': 48, 'negative': 64, 'ratio': 48.01538461538462},
#  'welcom': {'positive': 54, 'negative': 5, 'ratio': 54.166666666666664},
#  'stat': {'positive': 51, 'negative': 0, 'ratio': 52.0},
#  'arriv': {'positive': 57, 'negative': 4, 'ratio': 57.2},
#  '1': {'positive': 60, 'negative': 19, 'ratio': 60.05},
#  'unfollow': {'positive': 53, 'negative': 8, 'ratio': 53.111111111111114},
#  'via': {'positive': 60, 'negative': 1, 'ratio': 60.5},
#  'surpris': {'positive': 10, 'negative': 5, 'ratio': 10.166666666666666},
#  'sweet': {'positive': 16, 'negative': 5, 'ratio': 16.166666666666668},
#  '2': {'positive': 41, 'negative': 34, 'ratio': 41.02857142857143},
#  'plan': {'positive': 21, 'negative': 13, 'ratio': 21.071428571428573},
#  'proud': {'positive': 11, 'negative': 8, 'ratio': 11.11111111111111},
#  'least': {'positive': 14, 'negative': 13, 'ratio': 14.071428571428571},
#  'mayb': {'positive': 17, 'negative': 19, 'ratio': 17.05},
#  'sometim': {'positive': 11, 'negative': 15, 'ratio': 11.0625},
#  'let': {'positive': 57, 'negative': 31, 'ratio': 57.03125},
#  'around': {'positive': 14, 'negative': 17, 'ratio': 14.055555555555555},
#  '..': {'positive': 100, 'negative': 89, 'ratio': 100.0111111111111},
#  'side': {'positive': 13, 'negative': 6, 'ratio': 13.142857142857142},
#  'world': {'positive': 23, 'negative': 15, 'ratio': 23.0625},
#  'take': {'positive': 30, 'negative': 37, 'ratio': 30.026315789473685},
#  'care': {'positive': 12, 'negative': 13, 'ratio': 12.071428571428571},
#  'final': {'positive': 24, 'negative': 32, 'ratio': 24.03030303030303},
#  'fuck': {'positive': 20, 'negative': 47, 'ratio': 20.020833333333332},
#  'weekend': {'positive': 61, 'negative': 21, 'ratio': 61.04545454545455},
#  'real': {'positive': 18, 'negative': 17, 'ratio': 18.055555555555557},
#  'join': {'positive': 21, 'negative': 4, 'ratio': 21.2},
#  'might': {'positive': 21, 'negative': 10, 'ratio': 21.09090909090909},
#  'realli': {'positive': 66, 'negative': 103, 'ratio': 66.00961538461539},
#  'appreci': {'positive': 28, 'negative': 2, 'ratio': 28.333333333333332},
#  'share': {'positive': 41, 'negative': 8, 'ratio': 41.111111111111114},
#  'wow': {'positive': 14, 'negative': 4, 'ratio': 14.2},
#  'invit': {'positive': 15, 'negative': 1, 'ratio': 15.5},
#  'friend': {'positive': 40, 'negative': 30, 'ratio': 40.03225806451613},
#  'sleep': {'positive': 35, 'negative': 71, 'ratio': 35.013888888888886},
#  'birthday': {'positive': 53, 'negative': 16, 'ratio': 53.05882352941177},
#  'want': {'positive': 69, 'negative': 185, 'ratio': 69.00537634408602},
#  'cool': {'positive': 29, 'negative': 4, 'ratio': 29.2},
#  'luck': {'positive': 26, 'negative': 5, 'ratio': 26.166666666666668},
#  'glad': {'positive': 41, 'negative': 2, 'ratio': 41.333333333333336},
#  'done': {'positive': 40, 'negative': 18, 'ratio': 40.05263157894737},
#  'read': {'positive': 27, 'negative': 15, 'ratio': 27.0625},
#  'finish': {'positive': 15, 'negative': 10, 'ratio': 15.090909090909092},
#  'xx': {'positive': 33, 'negative': 15, 'ratio': 33.0625},
#  'miss': {'positive': 17, 'negative': 239, 'ratio': 17.004166666666666},
#  'sound': {'positive': 20, 'negative': 16, 'ratio': 20.058823529411764},
#  'morn': {'positive': 68, 'negative': 23, 'ratio': 68.04166666666667},
#  "that'": {'positive': 49, 'negative': 46, 'ratio': 49.02127659574468},
#  'definit': {'positive': 20, 'negative': 2, 'ratio': 20.333333333333332},
#  'tri': {'positive': 34, 'negative': 58, 'ratio': 34.016949152542374},
#  'tonight': {'positive': 15, 'negative': 20, 'ratio': 15.047619047619047},
#  'concert': {'positive': 23, 'negative': 9, 'ratio': 23.1},
#  'citi': {'positive': 26, 'negative': 11, 'ratio': 26.083333333333332},
#  'countri': {'positive': 22, 'negative': 5, 'ratio': 22.166666666666668},
#  "i'll": {'positive': 73, 'negative': 36, 'ratio': 73.02702702702703},
#  'start': {'positive': 56, 'negative': 37, 'ratio': 56.026315789473685},
#  'right': {'positive': 38, 'negative': 41, 'ratio': 38.023809523809526},
#  'back': {'positive': 74, 'negative': 98, 'ratio': 74.01010101010101},
#  'even': {'positive': 26, 'negative': 52, 'ratio': 26.0188679245283},
#  'cheer': {'positive': 17, 'negative': 3, 'ratio': 17.25},
#  'agre': {'positive': 13, 'negative': 4, 'ratio': 13.2},
#  'that': {'positive': 10, 'negative': 9, 'ratio': 10.1},
#  'point': {'positive': 11, 'negative': 9, 'ratio': 11.1},
#  'stay': {'positive': 20, 'negative': 21, 'ratio': 20.045454545454547},
#  'home': {'positive': 20, 'negative': 52, 'ratio': 20.0188679245283},
#  'soon': {'positive': 38, 'negative': 40, 'ratio': 38.02439024390244},
#  'later': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  'w': {'positive': 16, 'negative': 16, 'ratio': 16.058823529411764},
#  '3': {'positive': 26, 'negative': 31, 'ratio': 26.03125},
#  'team': {'positive': 24, 'negative': 13, 'ratio': 24.071428571428573},
#  'pass': {'positive': 10, 'negative': 12, 'ratio': 10.076923076923077},
#  'live': {'positive': 21, 'negative': 33, 'ratio': 21.029411764705884},
#  '5': {'positive': 15, 'negative': 11, 'ratio': 15.083333333333334},
#  'number': {'positive': 11, 'negative': 5, 'ratio': 11.166666666666666},
#  'wsalelov': {'positive': 14, 'negative': 5, 'ratio': 14.166666666666666},
#  'ah': {'positive': 12, 'negative': 15, 'ratio': 12.0625},
#  'anyway': {'positive': 14, 'negative': 10, 'ratio': 14.090909090909092},
#  'kinda': {'positive': 12, 'negative': 9, 'ratio': 12.1},
#  'life': {'positive': 36, 'negative': 29, 'ratio': 36.03333333333333},
#  'could': {'positive': 25, 'negative': 51, 'ratio': 25.01923076923077},
#  'alway': {'positive': 48, 'negative': 48, 'ratio': 48.02040816326531},
#  'smile': {'positive': 47, 'negative': 9, 'ratio': 47.1},
#  'song': {'positive': 16, 'negative': 25, 'ratio': 16.03846153846154},
#  'ever': {'positive': 19, 'negative': 25, 'ratio': 19.03846153846154},
#  'littl': {'positive': 29, 'negative': 17, 'ratio': 29.055555555555557},
#  'differ': {'positive': 10, 'negative': 9, 'ratio': 10.1},
#  "i'm": {'positive': 140, 'negative': 266, 'ratio': 140.00374531835206},
#  "let'": {'positive': 18, 'negative': 2, 'ratio': 18.333333333333332},
#  'travel': {'positive': 19, 'negative': 9, 'ratio': 19.1},
#  'wanna': {'positive': 23, 'negative': 76, 'ratio': 23.01298701298701},
#  'may': {'positive': 16, 'negative': 15, 'ratio': 16.0625},
#  'nice': {'positive': 70, 'negative': 17, 'ratio': 70.05555555555556},
#  'guy': {'positive': 48, 'negative': 45, 'ratio': 48.02173913043478},
#  'hour': {'positive': 24, 'negative': 26, 'ratio': 24.037037037037038},
#  'leav': {'positive': 11, 'negative': 31, 'ratio': 11.03125},
#  'actual': {'positive': 13, 'negative': 20, 'ratio': 13.047619047619047},
#  'blog': {'positive': 27, 'negative': 0, 'ratio': 28.0},
#  'complet': {'positive': 10, 'negative': 6, 'ratio': 10.142857142857142},
#  'hug': {'positive': 11, 'negative': 21, 'ratio': 11.045454545454545},
#  'connect': {'positive': 13, 'negative': 2, 'ratio': 13.333333333333334},
#  'wonder': {'positive': 26, 'negative': 9, 'ratio': 26.1},
#  'made': {'positive': 38, 'negative': 21, 'ratio': 38.04545454545455},
#  'trip': {'positive': 12, 'negative': 11, 'ratio': 12.083333333333334},
#  "i'd": {'positive': 13, 'negative': 10, 'ratio': 13.090909090909092},
#  'question': {'positive': 15, 'negative': 5, 'ratio': 15.166666666666666},
#  'went': {'positive': 10, 'negative': 27, 'ratio': 10.035714285714286},
#  'fav': {'positive': 11, 'negative': 0, 'ratio': 12.0},
#  'goodnight': {'positive': 18, 'negative': 1, 'ratio': 18.5},
#  'wake': {'positive': 10, 'negative': 18, 'ratio': 10.052631578947368},
#  'gonna': {'positive': 16, 'negative': 44, 'ratio': 16.022222222222222},
#  'much': {'positive': 73, 'negative': 116, 'ratio': 73.00854700854701},
#  'end': {'positive': 13, 'negative': 36, 'ratio': 13.027027027027026},
#  'rain': {'positive': 18, 'negative': 36, 'ratio': 18.027027027027028},
#  '♡': {'positive': 12, 'negative': 8, 'ratio': 12.11111111111111},
#  'idea': {'positive': 23, 'negative': 8, 'ratio': 23.11111111111111},
#  'game': {'positive': 23, 'negative': 25, 'ratio': 23.03846153846154},
#  'pic': {'positive': 21, 'negative': 14, 'ratio': 21.066666666666666},
#  'phone': {'positive': 16, 'negative': 26, 'ratio': 16.037037037037038},
#  'use': {'positive': 32, 'negative': 31, 'ratio': 32.03125},
#  'man': {'positive': 16, 'negative': 24, 'ratio': 16.04},
#  'turn': {'positive': 13, 'negative': 13, 'ratio': 13.071428571428571},
#  'omg': {'positive': 13, 'negative': 48, 'ratio': 13.020408163265307},
#  'say': {'positive': 43, 'negative': 47, 'ratio': 43.020833333333336},
#  'find': {'positive': 20, 'negative': 45, 'ratio': 20.02173913043478},
#  'cours': {'positive': 11, 'negative': 7, 'ratio': 11.125},
#  'info': {'positive': 10, 'negative': 1, 'ratio': 10.5},
#  'way': {'positive': 34, 'negative': 31, 'ratio': 34.03125},
#  'boy': {'positive': 13, 'negative': 10, 'ratio': 13.090909090909092},
#  'true': {'positive': 19, 'negative': 19, 'ratio': 19.05},
#  'peopl': {'positive': 42, 'negative': 57, 'ratio': 42.01724137931034},
#  'famili': {'positive': 14, 'negative': 9, 'ratio': 14.1},
#  'person': {'positive': 14, 'negative': 14, 'ratio': 14.066666666666666},
#  'two': {'positive': 15, 'negative': 13, 'ratio': 15.071428571428571},
#  'ya': {'positive': 19, 'negative': 11, 'ratio': 19.083333333333332},
#  "we'r": {'positive': 25, 'negative': 20, 'ratio': 25.047619047619047},
#  'also': {'positive': 28, 'negative': 17, 'ratio': 28.055555555555557},
#  'snapchat': {'positive': 31, 'negative': 64, 'ratio': 31.015384615384615},
#  'hot': {'positive': 20, 'negative': 9, 'ratio': 20.1},
#  'write': {'positive': 11, 'negative': 8, 'ratio': 11.11111111111111},
#  'sinc': {'positive': 11, 'negative': 33, 'ratio': 11.029411764705882},
#  'mention': {'positive': 18, 'negative': 6, 'ratio': 18.142857142857142},
#  'post': {'positive': 16, 'negative': 9, 'ratio': 16.1},
#  'though': {'positive': 16, 'negative': 44, 'ratio': 16.022222222222222},
#  'thankyou': {'positive': 12, 'negative': 2, 'ratio': 12.333333333333334},
#  'awww': {'positive': 12, 'negative': 19, 'ratio': 12.05},
#  'ha': {'positive': 18, 'negative': 6, 'ratio': 18.142857142857142},
#  'bad': {'positive': 14, 'negative': 54, 'ratio': 14.018181818181818},
#  'mine': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  'account': {'positive': 17, 'negative': 17, 'ratio': 17.055555555555557},
#  'everyth': {'positive': 10, 'negative': 14, 'ratio': 10.066666666666666},
#  "they'r": {'positive': 10, 'negative': 13, 'ratio': 10.071428571428571},
#  'updat': {'positive': 12, 'negative': 10, 'ratio': 12.090909090909092},
#  'bring': {'positive': 12, 'negative': 8, 'ratio': 12.11111111111111},
#  'meet': {'positive': 26, 'negative': 22, 'ratio': 26.043478260869566},
#  'eye': {'positive': 12, 'negative': 11, 'ratio': 12.083333333333334},
#  'funni': {'positive': 15, 'negative': 4, 'ratio': 15.2},
#  'happen': {'positive': 13, 'negative': 43, 'ratio': 13.022727272727273},
#  'play': {'positive': 37, 'negative': 39, 'ratio': 37.025},
#  'fan': {'positive': 21, 'negative': 17, 'ratio': 21.055555555555557},
#  'brain': {'positive': 10, 'negative': 2, 'ratio': 10.333333333333334},
#  'either': {'positive': 10, 'negative': 11, 'ratio': 10.083333333333334},
#  'put': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  'free': {'positive': 31, 'negative': 14, 'ratio': 31.066666666666666},
#  '8': {'positive': 10, 'negative': 7, 'ratio': 10.125},
#  '♥': {'positive': 13, 'negative': 20, 'ratio': 13.047619047619047},
#  "he'": {'positive': 10, 'negative': 19, 'ratio': 10.05},
#  'caus': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  'ff': {'positive': 40, 'negative': 4, 'ratio': 40.2},
#  'kind': {'positive': 22, 'negative': 9, 'ratio': 22.1},
#  'word': {'positive': 17, 'negative': 13, 'ratio': 17.071428571428573},
#  'open': {'positive': 12, 'negative': 12, 'ratio': 12.076923076923077},
#  'show': {'positive': 20, 'negative': 19, 'ratio': 20.05},
#  'first': {'positive': 41, 'negative': 22, 'ratio': 41.04347826086956},
#  'awesom': {'positive': 35, 'negative': 5, 'ratio': 35.166666666666664},
#  'stream': {'positive': 12, 'negative': 21, 'ratio': 12.045454545454545},
#  'everi': {'positive': 23, 'negative': 11, 'ratio': 23.083333333333332},
#  'readi': {'positive': 22, 'negative': 9, 'ratio': 22.1},
#  'tomorrow': {'positive': 31, 'negative': 26, 'ratio': 31.037037037037038},
#  'fback': {'positive': 26, 'negative': 0, 'ratio': 27.0},
#  'head': {'positive': 12, 'negative': 18, 'ratio': 12.052631578947368},
#  'saw': {'positive': 16, 'negative': 15, 'ratio': 16.0625},
#  'cant': {'positive': 13, 'negative': 41, 'ratio': 13.023809523809524},
#  'list': {'positive': 10, 'negative': 3, 'ratio': 10.25},
#  'photo': {'positive': 16, 'negative': 11, 'ratio': 16.083333333333332},
#  'thx': {'positive': 12, 'negative': 1, 'ratio': 12.5},
#  '4': {'positive': 21, 'negative': 16, 'ratio': 21.058823529411764},
#  'give': {'positive': 42, 'negative': 27, 'ratio': 42.035714285714285},
#  'mind': {'positive': 13, 'negative': 4, 'ratio': 13.2},
#  'quit': {'positive': 11, 'negative': 7, 'ratio': 11.125},
#  'sorri': {'positive': 13, 'negative': 117, 'ratio': 13.008474576271187},
#  'old': {'positive': 12, 'negative': 12, 'ratio': 12.076923076923077},
#  'bro': {'positive': 19, 'negative': 3, 'ratio': 19.25},
#  '2015': {'positive': 13, 'negative': 11, 'ratio': 13.083333333333334},
#  'book': {'positive': 14, 'negative': 16, 'ratio': 14.058823529411764},
#  'moment': {'positive': 10, 'negative': 13, 'ratio': 10.071428571428571},
#  'design': {'positive': 18, 'negative': 3, 'ratio': 18.25},
#  'download': {'positive': 10, 'negative': 2, 'ratio': 10.333333333333334},
#  'ur': {'positive': 29, 'negative': 19, 'ratio': 29.05},
#  'bodi': {'positive': 12, 'negative': 11, 'ratio': 12.083333333333334},
#  'order': {'positive': 12, 'negative': 14, 'ratio': 12.066666666666666},
#  'hahaha': {'positive': 11, 'negative': 11, 'ratio': 11.083333333333334},
#  'stori': {'positive': 10, 'negative': 11, 'ratio': 10.083333333333334},
#  'month': {'positive': 11, 'negative': 18, 'ratio': 11.052631578947368},
#  'yay': {'positive': 15, 'negative': 3, 'ratio': 15.25},
#  'feedback': {'positive': 10, 'negative': 4, 'ratio': 10.2},
#  'retweet': {'positive': 25, 'negative': 5, 'ratio': 25.166666666666668},
#  'tweet': {'positive': 47, 'negative': 28, 'ratio': 47.03448275862069},
#  'found': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  '6': {'positive': 17, 'negative': 10, 'ratio': 17.09090909090909},
#  'full': {'positive': 17, 'negative': 11, 'ratio': 17.083333333333332},
#  'interest': {'positive': 16, 'negative': 5, 'ratio': 16.166666666666668},
#  'win': {'positive': 12, 'negative': 23, 'ratio': 12.041666666666666},
#  'worri': {'positive': 17, 'negative': 5, 'ratio': 17.166666666666668},
#  'excit': {'positive': 28, 'negative': 4, 'ratio': 28.2},
#  'xxx': {'positive': 13, 'negative': 8, 'ratio': 13.11111111111111},
#  'summer': {'positive': 12, 'negative': 13, 'ratio': 12.071428571428571},
#  'anyth': {'positive': 18, 'negative': 16, 'ratio': 18.058823529411764},
#  'dont': {'positive': 11, 'negative': 39, 'ratio': 11.025},
#  '10': {'positive': 15, 'negative': 7, 'ratio': 15.125},
#  'problem': {'positive': 17, 'negative': 6, 'ratio': 17.142857142857142},
#  'ok': {'positive': 29, 'negative': 25, 'ratio': 29.03846153846154},
#  'r': {'positive': 13, 'negative': 11, 'ratio': 13.083333333333334},
#  'n': {'positive': 13, 'negative': 17, 'ratio': 13.055555555555555},
#  'forget': {'positive': 16, 'negative': 5, 'ratio': 16.166666666666668},
#  'close': {'positive': 12, 'negative': 16, 'ratio': 12.058823529411764},
#  '–': {'positive': 14, 'negative': 1, 'ratio': 14.5},
#  'place': {'positive': 19, 'negative': 12, 'ratio': 19.076923076923077},
#  'tho': {'positive': 10, 'negative': 24, 'ratio': 10.04},
#  '❤': {'positive': 21, 'negative': 15, 'ratio': 21.0625},
#  '️': {'positive': 12, 'negative': 13, 'ratio': 12.071428571428571},
#  'add': {'positive': 19, 'negative': 20, 'ratio': 19.047619047619047},
#  'news': {'positive': 16, 'negative': 18, 'ratio': 16.05263157894737},
#  'ticket': {'positive': 10, 'negative': 9, 'ratio': 10.1},
#  'favorit': {'positive': 10, 'negative': 3, 'ratio': 10.25},
#  'sir': {'positive': 10, 'negative': 5, 'ratio': 10.166666666666666},
#  'ask': {'positive': 26, 'negative': 22, 'ratio': 26.043478260869566},
#  'tell': {'positive': 22, 'negative': 20, 'ratio': 22.047619047619047},
#  'far': {'positive': 14, 'negative': 16, 'ratio': 14.058823529411764},
#  'stop': {'positive': 14, 'negative': 35, 'ratio': 14.027777777777779},
#  'anoth': {'positive': 16, 'negative': 17, 'ratio': 16.055555555555557},
#  'movi': {'positive': 17, 'negative': 17, 'ratio': 17.055555555555557},
#  'noth': {'positive': 13, 'negative': 19, 'ratio': 13.05},
#  'follback': {'positive': 18, 'negative': 1, 'ratio': 18.5},
#  'store': {'positive': 12, 'negative': 3, 'ratio': 12.25},
#  'hit': {'positive': 11, 'negative': 3, 'ratio': 11.25},
#  '😂': {'positive': 11, 'negative': 14, 'ratio': 11.066666666666666},
#  'busi': {'positive': 15, 'negative': 21, 'ratio': 15.045454545454545},
#  'said': {'positive': 15, 'negative': 29, 'ratio': 15.033333333333333},
#  'late': {'positive': 12, 'negative': 24, 'ratio': 12.04},
#  'coffe': {'positive': 10, 'negative': 1, 'ratio': 10.5},
#  'shit': {'positive': 11, 'negative': 26, 'ratio': 11.037037037037036},
#  'date': {'positive': 10, 'negative': 6, 'ratio': 10.142857142857142},
#  'super': {'positive': 13, 'negative': 4, 'ratio': 13.2},
#  'part': {'positive': 13, 'negative': 10, 'ratio': 13.090909090909092},
#  'away': {'positive': 11, 'negative': 22, 'ratio': 11.043478260869565},
#  'run': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  'mean': {'positive': 19, 'negative': 39, 'ratio': 19.025},
#  'pleasur': {'positive': 10, 'negative': 0, 'ratio': 11.0},
#  'pick': {'positive': 11, 'negative': 10, 'ratio': 11.090909090909092},
#  'view': {'positive': 13, 'negative': 6, 'ratio': 13.142857142857142},
#  'walk': {'positive': 10, 'negative': 6, 'ratio': 10.142857142857142},
#  'juli': {'positive': 11, 'negative': 12, 'ratio': 11.076923076923077},
#  '💕': {'positive': 10, 'negative': 5, 'ratio': 10.166666666666666}}

# %% [markdown]
# Notice the difference between the positive and negative ratios. Emojis like :( and words like 'me' tend to have a negative connotation. Other words like 'glad', 'community', and 'arrives' tend to be found in the positive tweets.

# %% [markdown]
# # Part 5: Error Analysis
#
# In this part you will see some tweets that your model missclassified. Why do you think the misclassifications happened? Were there any assumptions made by the naive bayes model?

# %%
# Some error analysis done for you
print('Truth Predicted Tweet')
for x, y in zip(test_x, test_y):
    y_hat = naive_bayes_predict(x, logprior, loglikelihood)
    if y != (np.sign(y_hat) > 0):
        print('%d\t%0.2f\t%s' % (y, np.sign(y_hat) > 0, ' '.join(
            process_tweet(x)).encode('ascii', 'ignore')))
# Out:
# Truth Predicted Tweet
# 1	0.00	b''
# 1	0.00	b'truli later move know queen bee upward bound movingonup'
# 1	0.00	b'new report talk burn calori cold work harder warm feel better weather :p'
# 1	0.00	b'harri niall 94 harri born ik stupid wanna chang :D'
# 1	0.00	b''
# 1	0.00	b''
# 1	0.00	b'park get sunlight'
# 1	0.00	b'uff itna miss karhi thi ap :p'
# 0	1.00	b'hello info possibl interest jonatha close join beti :( great'
# 0	1.00	b'u prob fun david'
# 0	1.00	b'pat jay'
# 0	1.00	b'whatev stil l young >:-('

# %% [markdown]
# # Part 6: Predict with your own tweet
#
# In this part you can predict the sentiment of your own tweet.

# %%
# Test with your own tweet - feel free to modify `my_tweet`
my_tweet = 'I am happy because I am learning :)'

p = naive_bayes_predict(my_tweet, logprior, loglikelihood)
print(p)
# Out:
# 9.574768961173337

# %% [markdown]
# Congratulations on completing this assignment. See you next week!
